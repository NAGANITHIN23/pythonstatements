# %%
x=1
y=1
x>=y
if x:
    print("welcome")
else:
    print("no")
# Out:
# welcome

# %%
Y = 'ZXY'

if Y == 'ABC':
    print('HELLO WORLD')
elif Y == 'ZXY':
    print('WELCOME')
else:
    print('Where are you?')
# Out:
# WELCOME
